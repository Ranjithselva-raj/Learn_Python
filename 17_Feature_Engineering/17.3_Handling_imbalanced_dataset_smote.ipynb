# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
# #### SMOTE (Synthetic Minority Oversampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_samples=1000, n_features=2, n_clusters_per_class=1, weights= [0.90], n_redundant=0  ,random_state=12)

# %%
import pandas as pd
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])

final_df = pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
plt.show()

# %%
#!pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ranje\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)

# %%
import sys
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ranje\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ranje\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)

# %%
pip show imbalanced-learn
# Out:
# Name: imbalanced-learnNote: you may need to restart the kernel to use updated packages.
#
# Version: 0.10.1
# Summary: Toolbox for imbalanced dataset in machine learning.
# Home-page: https://github.com/scikit-learn-contrib/imbalanced-learn
# Author:
# Author-email:
# License: MIT
# Location: c:\Users\ranje\anaconda3\Lib\site-packages
# Requires: joblib, numpy, scikit-learn, scipy, threadpoolctl
# Required-by:

# %%
from imblearn.over_sampling import SMOTE

# %%
## transform the dataset

oversample = SMOTE()
x,y = oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])

oversample_df = pd.concat([df1,df2],axis=1)
oversample_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])
plt.show()
